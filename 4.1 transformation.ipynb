# %%
# %ls Data
# Out:
#  驱动器 C 中的卷是 OS
#  卷的序列号是 BCF3-9DDE
#
#  C:\Users\zhesiwode\Desktop\jupter\Data 的目录
#
# 2023/07/03  16:35    <DIR>          .
# 2023/07/03  16:35    <DIR>          ..
# 2023/07/01  16:32    <DIR>          .ipynb_checkpoints
# 2023/07/01  16:39             9,331 GDP.xlsx
# 2023/07/03  14:41            47,868 house_data.csv
# 2023/07/03  16:32            14,551 house_sample.xlsx
# 2023/07/01  16:46            19,251 jd.json
# 2023/07/01  16:25               509 Population.csv
# 2023/07/01  16:58             5,827 weather.xml
#                6 个文件         97,337 字节
#                3 个目录 137,007,886,336 可用字节

# %%
import pandas as pd
df = pd.read_excel('Data/house_sample.xlsx')
df.head()
# Out:
#    Unnamed: 0                              标题    建筑面积   总价        户型  ...    环比上月          张贴日期  产权性质    装修  楼层
# 0           0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1           1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...  ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2           2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...  ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3           3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...  ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4           4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层
#
# [5 rows x 12 columns]

# %%
df['总价']*10000
# Out:
# 0     7600000
# 1      760000
# 2      800000
# 3      800000
# 4     2850000
# 5     2950000
# 6     2400000
# 7     4100000
# 8     4000000
# 9     2700000
# 10    3000000
# 11    2850000
# 12    3400000
# 13    3550000
# 14    8500000
# 15    3590000
# 16    3600000
# 17    6100000
# 18    7700000
# 19    2200000
# 20    2360000
# 21    2980000
# 22    3250000
# 23    4580000
# 24    5600000
# 25    6500000
# 26    2000000
# 27    2550000
# 28    4500000
# Name: 总价, dtype: int64

# %%
import numpy as np
np.sqrt(df['总价'])
# Out:
# 0     27.568098
# 1      8.717798
# 2      8.944272
# 3      8.944272
# 4     16.881943
# 5     17.175564
# 6     15.491933
# 7     20.248457
# 8     20.000000
# 9     16.431677
# 10    17.320508
# 11    16.881943
# 12    18.439089
# 13    18.841444
# 14    29.154759
# 15    18.947295
# 16    18.973666
# 17    24.698178
# 18    27.748874
# 19    14.832397
# 20    15.362291
# 21    17.262677
# 22    18.027756
# 23    21.400935
# 24    23.664319
# 25    25.495098
# 26    14.142136
# 27    15.968719
# 28    21.213203
# Name: 总价, dtype: float64

# %%
df['朝向']+df['户型']
# Out:
# 0     南北3室2厅0厨2卫
# 1     南北2室2厅1厨1卫
# 2     南北3室2厅1厨2卫
# 3     南北2室1厅1厨1卫
# 4      南2室1厅1厨1卫
# 5     南北3室1厅1厨1卫
# 6      南2室1厅1厨1卫
# 7      南3室1厅1厨1卫
# 8      南2室2厅1厨1卫
# 9     南北1室1厅1厨1卫
# 10    南北2室1厅1厨1卫
# 11     南1室1厅1厨1卫
# 12    南北1室1厅1厨1卫
# 13    南北2室1厅1厨1卫
# 14    南北3室2厅1厨2卫
# 15     南2室1厅1厨1卫
# 16     南2室1厅1厨1卫
# 17    南北2室2厅1厨1卫
# 18     南3室2厅0厨2卫
# 19     南1室0厅1厨1卫
# 20    南北2室2厅1厨1卫
# 21     南1室2厅1厨1卫
# 22     南1室2厅1厨1卫
# 23    南北3室2厅1厨1卫
# 24    南北3室2厅1厨2卫
# 25     南2室2厅1厨2卫
# 26     南1室1厅1厨1卫
# 27    南北2室1厅1厨1卫
# 28     南2室1厅0厨1卫
# dtype: object

# %%
df['均价'] = df['总价']*10000/df['建筑面积']

# %%
df
# Out:
#     Unnamed: 0                                标题    建筑面积   总价        户型  ...          张贴日期  产权性质    装修  楼层            均价
# 0            0      资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...  西元2017年4月12日   商品房  豪华装修  低层  61538.461538
# 1            1       未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...  西元2017年4月13日   商品房   精装修  中层   8837.209302
# 2            2        双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...  西元2017年4月14日   商品房   精装修  高层   8888.888889
# 3            3        坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...  西元2017年4月15日   商品房   简装修  中层   8888.888889
# 4            4    对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...  西元2017年4月16日  个人产权   中装修  低层  42786.368413
# 5            5    精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  ...  西元2017年4月17日  个人产权   精装修  中层  40972.222222
# 6            6  精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫  ...  西元2017年4月18日  个人产权   精装修  中层  36596.523330
# ...

# %%
def remove(e):
    return e.split('元')[0]
df['物 业 费']=df['物 业 费'].map(remove)

# %%
df
# Out:
#     Unnamed: 0                                标题    建筑面积   总价        户型  ...          张贴日期  产权性质    装修  楼层            均价
# 0            0      资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...  西元2017年4月12日   商品房  豪华装修  低层  61538.461538
# 1            1       未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...  西元2017年4月13日   商品房   精装修  中层   8837.209302
# 2            2        双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...  西元2017年4月14日   商品房   精装修  高层   8888.888889
# 3            3        坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...  西元2017年4月15日   商品房   简装修  中层   8888.888889
# 4            4    对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...  西元2017年4月16日  个人产权   中装修  低层  42786.368413
# 5            5    精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  ...  西元2017年4月17日  个人产权   精装修  中层  40972.222222
# 6            6  精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫  ...  西元2017年4月18日  个人产权   精装修  中层  36596.523330
# ...

# %%
df['物 业 费']=df['物 业 费'].map(lambda e:e.split('元')[0])
df
# Out:
#     Unnamed: 0                                标题    建筑面积   总价        户型  ...          张贴日期  产权性质    装修  楼层            均价
# 0            0      资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...  西元2017年4月12日   商品房  豪华装修  低层  61538.461538
# 1            1       未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...  西元2017年4月13日   商品房   精装修  中层   8837.209302
# 2            2        双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...  西元2017年4月14日   商品房   精装修  高层   8888.888889
# 3            3        坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...  西元2017年4月15日   商品房   简装修  中层   8888.888889
# 4            4    对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...  西元2017年4月16日  个人产权   中装修  低层  42786.368413
# 5            5    精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  ...  西元2017年4月17日  个人产权   精装修  中层  40972.222222
# 6            6  精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫  ...  西元2017年4月18日  个人产权   精装修  中层  36596.523330
# ...

# %%
df = pd.DataFrame([
                    [60,70,50],\
                    [80,79,68],\
                    [63,66,82]], columns = ['First', 'Second', 'Third'])
df
# Out:
#    First  Second  Third
# 0     60      70     50
# 1     80      79     68
# 2     63      66     82

# %%
df.apply(lambda e:e.max()-e.min())
# Out:
# First     20
# Second    13
# Third     32
# dtype: int64

# %%
df.apply(lambda e:e.max()-e.min(),axis=1)
# Out:
# 0    20
# 1    12
# 2    19
# dtype: int64

# %%
import pandas as pd
df = pd.read_excel('Data/house_sample.xlsx')
df.head()
# Out:
#    Unnamed: 0                              标题    建筑面积   总价        户型  ...    环比上月          张贴日期  产权性质    装修  楼层
# 0           0    资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...  ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1           1     未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...  ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2           2      双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...  ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3           3      坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...  ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4           4  对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...  ↓2.62%  西元2017年4月16日  个人产权   中装修  低层
#
# [5 rows x 12 columns]

# %%
def nam(e):
    if e=='暂无资料':
        return np.nan
    else: 
        return e
df.applymap(nam)
# Out:
#     Unnamed: 0                                标题    建筑面积   总价        户型  ...     环比上月          张贴日期  产权性质    装修  楼层
# 0            0      资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...   ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1            1       未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...   ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2            2        双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...   ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3            3        坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...   ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4            4    对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...   ↓2.62%  西元2017年4月16日  个人产权   中装修  低层
# 5            5    精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  ...   ↑1.64%  西元2017年4月17日  个人产权   精装修  中层
# 6            6  精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫  ...   ↓1.52%  西元2017年4月18日  个人产权   精装修  中层
# ...

# %%
df.applymap(lambda e:np.nan if e=='暂无资料' else e)
# Out:
#     Unnamed: 0                                标题    建筑面积   总价        户型  ...     环比上月          张贴日期  产权性质    装修  楼层
# 0            0      资深经纪上海人：稀缺3房，南北通透采光好，房东急需用钱！  123.50  760  3室2厅0厨2卫  ...   ↑1.44%  西元2017年4月12日   商品房  豪华装修  低层
# 1            1       未来规划小上海，精装带地暖，养老，亲子，旅游度假一体化   86.00   76  2室2厅1厨1卫  ...   ↑4.08%  西元2017年4月13日   商品房   精装修  中层
# 2            2        双高铁 不限贷 买一层送一层 送大露台 看房专车接送   90.00   80  3室2厅1厨2卫  ...   ↓0.01%  西元2017年4月14日   商品房   精装修  高层
# 3            3        坐拥嘉兴海宁双轨 享受市区配套 现房值得拥有 可落户   90.00   80  2室1厅1厨1卫  ...   ↓0.01%  西元2017年4月15日   商品房   简装修  中层
# 4            4    对口明强校区，精装两房税费少，位置安静，媲美园艺新村，随时看   66.61  285  2室1厅1厨1卫  ...   ↓2.62%  西元2017年4月16日  个人产权   中装修  低层
# 5            5    精装三房，精装修全送， 边套全明，小区中心位置，采光无遮挡！   72.00  295  3室1厅1厨1卫  ...   ↑1.64%  西元2017年4月17日  个人产权   精装修  中层
# 6            6  精装两年 楼下有固定车位 接受置换 中间楼层 双南户型 底价诚售   65.58  240  2室1厅1厨1卫  ...   ↓1.52%  西元2017年4月18日  个人产权   精装修  中层
# ...
