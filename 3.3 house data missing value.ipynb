# %%
import pandas as pd
df = pd.read_csv('Data/house_data.csv')
df
# Out:
#      Unnamed: 0                                標題  产权性质   住宅类别 建筑类别  参考月供  \
# 0             0     急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼   NaN
# 1             1          世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权   普通住宅   塔楼   NaN
# 2             2                 大四房出售，带会所+高区景观+车位  个人产权   普通住宅  NaN   NaN
# 3             3          精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房    NaN   板楼   NaN
# 4             4      满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权   普通住宅   钢混   NaN
# ..          ...                               ...   ...    ...  ...   ...
# 235         235  年后降价急售―150万硬装+中央空调+地暖―120平花园―双车位   NaN    NaN  NaN   NaN
# 236         236                       11号线地铁口 可贷款  个人产权  酒店式公寓   板楼   NaN
# 237         237    6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权   普通住宅   钢混   NaN
# 238         238         业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权   普通住宅   板楼   NaN
# 239         239     区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权   普通住宅   板楼   NaN
#
#         年代    建筑面积        户型        楼层       物 业 费 物业类型   结构   装修      總價
# ...

# %%
df.head(3)
# Out:
#    Unnamed: 0                             標題  产权性质  住宅类别 建筑类别  参考月供     年代  \
# 0           0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年
# 1           1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年
# 2           2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年
#
#      建筑面积        户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0   70.40  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1   49.82  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  288.30  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df = pd.read_csv('Data/house_data.csv',index_col=0)
df
# Out:
#                                    標題  产权性质   住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0       急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼   NaN  1989年   70.40
# 1            世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权   普通住宅   塔楼   NaN  1989年   49.82
# 2                   大四房出售，带会所+高区景观+车位  个人产权   普通住宅  NaN   NaN  2005年  288.30
# 3            精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房    NaN   板楼   NaN  1994年   56.00
# 4        满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权   普通住宅   钢混   NaN  1998年   58.00
# ..                                ...   ...    ...  ...   ...    ...     ...
# 235  年后降价急售―150万硬装+中央空调+地暖―120平花园―双车位   NaN    NaN  NaN   NaN    NaN  214.00
# 236                       11号线地铁口 可贷款  个人产权  酒店式公寓   板楼   NaN  2015年   45.00
# 237    6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权   普通住宅   钢混   NaN  2005年   96.82
# 238         业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权   普通住宅   板楼   NaN  2002年  168.00
# 239     区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权   普通住宅   板楼   NaN  1996年   43.13
#
# ...

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['物 业 费']=='暂无资料'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 235    False
# 236    False
# 237    False
# 238    False
# 239    False
# Name: 物 业 费, Length: 240, dtype: bool

# %%
df[df['物 业 费']=='暂无资料']
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
import numpy as np
df.loc[df['物 业 费'] == '暂无资料', '物 业 费'] = np.nan 
df.head(2)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代   建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年  70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年  49.82
#
#          户型       楼层    物 业 费 物业类型  结构   装修     總價
# 0  2室2厅1厨1卫  中层(共6层)      NaN   住宅  平层  精装修   30.6
# 1  2室1厅0厨1卫  中层(共6层)  1元/平米・月   住宅  平层  简装修  418.0

# %%
df = pd.read_csv('Data/house_data.csv',na_values='暂无资料',index_col=0)
df.head(2)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代   建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年  70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年  49.82
#
#          户型       楼层    物 业 费 物业类型  结构   装修     總價
# 0  2室2厅1厨1卫  中层(共6层)      NaN   住宅  平层  精装修   30.6
# 1  2室1厅0厨1卫  中层(共6层)  1元/平米・月   住宅  平层  简装修  418.0

# %%
df.tail(3)
# Out:
#                                  標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 237  6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权  普通住宅   钢混   NaN  2005年   96.82
# 238       业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权  普通住宅   板楼   NaN  2002年  168.00
# 239   区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权  普通住宅   板楼   NaN  1996年   43.13
#
#            户型        楼层       物 业 费 物业类型  结构   装修      總價
# 237  2室2厅1厨1卫   高层(共8层)  1.86元/平米・月   住宅  平层  精装修   460.0
# 238  3室2厅1厨2卫  高层(共20层)     2元/平米・月   住宅  平层  简装修  1250.0
# 239  1室1厅1厨1卫   高层(共7层)   0.3元/平米・月   住宅  平层  简装修   278.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   標題      240 non-null    object
#  1   产权性质    228 non-null    object
#  2   住宅类别    218 non-null    object
#  3   建筑类别    188 non-null    object
#  4   参考月供    0 non-null      float64
#  5   年代      224 non-null    object
#  6   建筑面积    240 non-null    float64
#  7   户型      240 non-null    object
#  8   楼层      228 non-null    object
#  9   物 业 费   215 non-null    object
#  10  物业类型    240 non-null    object
#  11  结构      181 non-null    object
#  12  装修      228 non-null    object
#  13  總價      237 non-null    float64
# dtypes: float64(3), object(11)
# memory usage: 28.1+ KB

# %%
df.dtypes
# Out:
# 標題        object
# 产权性质      object
# 住宅类别      object
# 建筑类别      object
# 参考月供     float64
# 年代        object
# 建筑面积     float64
# 户型        object
# 楼层        object
# 物 业 费     object
# 物业类型      object
# 结构        object
# 装修        object
# 總價       float64
# dtype: object

# %%
df.columns
# Out:
# Index(['標題', '产权性质', '住宅类别', '建筑类别', '参考月供', '年代', '建筑面积', '户型', '楼层', '物 业 费',
#        '物业类型', '结构', '装修', '總價'],
#       dtype='object')

# %%
df.describe()
# Out:
#        参考月供        建筑面积            總價
# count   0.0  240.000000    237.000000
# mean    NaN  113.435333    646.092869
# std     NaN   99.199836   1300.349319
# min     NaN   22.500000     30.600000
# 25%     NaN   68.952500    220.000000
# 50%     NaN   88.155000    400.000000
# 75%     NaN  123.250000    578.000000
# max     NaN  731.240000  11000.000000

# %%
df.isnull().any()
# Out:
# 標題       False
# 产权性质      True
# 住宅类别      True
# 建筑类别      True
# 参考月供      True
# 年代        True
# 建筑面积     False
# 户型       False
# 楼层        True
# 物 业 费     True
# 物业类型     False
# 结构        True
# 装修        True
# 總價        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# 標題         0
# 产权性质      12
# 住宅类别      22
# 建筑类别      52
# 参考月供     240
# 年代        16
# 建筑面积       0
# 户型         0
# 楼层        12
# 物 业 费     25
# 物业类型       0
# 结构        59
# 装修        12
# 總價         3
# dtype: int64

# %%
df.isnull().sum()/df.count()
# Out:
# 標題       0.000000
# 产权性质     0.052632
# 住宅类别     0.100917
# 建筑类别     0.276596
# 参考月供          inf
# 年代       0.071429
# 建筑面积     0.000000
# 户型       0.000000
# 楼层       0.052632
# 物 业 费    0.116279
# 物业类型     0.000000
# 结构       0.325967
# 装修       0.052632
# 總價       0.012658
# dtype: float64

# %%
df
# Out:
#                                    標題  产权性质   住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0       急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼   NaN  1989年   70.40
# 1            世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权   普通住宅   塔楼   NaN  1989年   49.82
# 2                   大四房出售，带会所+高区景观+车位  个人产权   普通住宅  NaN   NaN  2005年  288.30
# 3            精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房    NaN   板楼   NaN  1994年   56.00
# 4        满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权   普通住宅   钢混   NaN  1998年   58.00
# ..                                ...   ...    ...  ...   ...    ...     ...
# 235  年后降价急售―150万硬装+中央空调+地暖―120平花园―双车位   NaN    NaN  NaN   NaN    NaN  214.00
# 236                       11号线地铁口 可贷款  个人产权  酒店式公寓   板楼   NaN  2015年   45.00
# 237    6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权   普通住宅   钢混   NaN  2005年   96.82
# 238         业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权   普通住宅   板楼   NaN  2002年  168.00
# 239     区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权   普通住宅   板楼   NaN  1996年   43.13
#
# ...

# %%
df = df.drop('参考月供',axis=1)
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权     171
# 商品房       54
# 经济适用房      2
# 售后公房       1
# Name: 产权性质, dtype: int64

# %%
df[df['产权性质']=='个人产权'].head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df.iloc[12:18]
# Out:
#                                   標題  产权性质  住宅类别 建筑类别     年代    建筑面积  \
# 12            月浦八村繁华地段 毗邻公园双南两房 双轨交通  个人产权  普通住宅  NaN  1991年   47.12
# 13  新出房源 房东置换 新房已看好 放价10万 诚心出售 满五税费少  个人产权  普通住宅   板楼  1995年   35.12
# 14      开发商内部保留房,一手房更名,全新豪华装修！带产权车位！  个人产权  普通住宅   钢混  2017年  123.00
# 15      艺泰安邦，精装修南北通房东保养不错可拎包住房子满五税费少  个人产权  普通住宅   板楼  2012年   87.00
# 16           1号线，闸北公园景观房，十院，精装修，生活便利  个人产权  普通住宅   板楼  2002年  103.00
# 17        新出长桥八村一房一厅 全明四楼 房东置换急卖 徐教院  个人产权  普通住宅   板楼  1996年   45.00
#
#           户型        楼层      物 业 费 物业类型   结构   装修     總價
# 12  2室0厅0厨1卫   高层(共6层)  0.6元/平米・月   住宅  NaN  中装修  180.0
# 13  1室1厅1厨1卫   中层(共6层)  0.5元/平米・月   住宅   平层  精装修  185.0
# 14  3室2厅1厨2卫  中层(共16层)    4.8元/・月   住宅   平层  精装修  508.0
# 15  2室2厅1厨1卫  低层(共18层)  1.4元/平米・月   住宅   平层  精装修  270.0
# 16  2室2厅1厨1卫  中层(共28层)  1.5元/平米・月   住宅   平层  精装修  700.0
# 17  1室1厅1厨1卫   中层(共6层)  0.8元/平米・月   住宅   平层  简装修  258.0

# %%
df.loc[(df['建筑面积']>100)&(df['總價']>2000),].head(2)
# Out:
#                                 標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型  \
# 2                大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫
# 11  绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派   NaN   NaN  NaN    NaN  502.0  5室3厅2厨6卫
#
#           楼层       物 业 费 物业类型   结构   装修      總價
# 2   高层(共40层)   3.5元/平米・月   住宅  NaN  精装修  2650.0
# 11       NaN  6.5元/平方米・月   别墅  NaN  NaN  2798.0

# %%
df[(df['建筑面积']>100)&(df['總價']>2000)].head(2)
# Out:
#                                 標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型  \
# 2                大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫
# 11  绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派   NaN   NaN  NaN    NaN  502.0  5室3厅2厨6卫
#
#           楼层       物 业 费 物业类型   结构   装修      總價
# 2   高层(共40层)   3.5元/平米・月   住宅  NaN  精装修  2650.0
# 11       NaN  6.5元/平方米・月   别墅  NaN  NaN  2798.0

# %%
df[df['建筑面积']>100].head(1)
# Out:
#                   標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型        楼层  \
# 2  大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫  高层(共40层)
#
#        物 业 费 物业类型   结构   装修      總價
# 2  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df = df[df['产权性质']=='个人产权']
df
# Out:
#                                  標題  产权性质   住宅类别 建筑类别     年代    建筑面积  \
# 0     急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼  1989年   70.40
# 1          世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权   普通住宅   塔楼  1989年   49.82
# 2                 大四房出售，带会所+高区景观+车位  个人产权   普通住宅  NaN  2005年  288.30
# 4      满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权   普通住宅   钢混  1998年   58.00
# 7              纪联小区，，大一房一厅，精装修，，！诚售  个人产权   普通住宅   板楼  1996年   50.00
# ..                              ...   ...    ...  ...    ...     ...
# 234  人生至少要有两次冲动，一场奋不顾身的爱情和一次说买就买的房子  个人产权   普通住宅   钢混  2003年  182.44
# 236                     11号线地铁口 可贷款  个人产权  酒店式公寓   板楼  2015年   45.00
# 237  6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权   普通住宅   钢混  2005年   96.82
# 238       业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权   普通住宅   板楼  2002年  168.00
# 239   区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权   普通住宅   板楼  1996年   43.13
#
#            户型        楼层       物 业 费 物业类型   结构   装修      總價
# 0    2室2厅1厨1卫   中层(共6层)         NaN   住宅   平层  精装修    30.6
# ...

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权    171
# Name: 产权性质, dtype: int64

# %%
df[df['建筑类别'].isnull()].head()
# Out:
#                                    標題  产权性质  住宅类别 建筑类别     年代    建筑面积  \
# 2                   大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30
# 12             月浦八村繁华地段 毗邻公园双南两房 双轨交通  个人产权  普通住宅  NaN  1991年   47.12
# 27     投咨300亿山水六旗主题公园 金色海岸 海景房 得房率110  个人产权  普通住宅  NaN  2016年   84.00
# 60  华府天地主营专员+价格可谈+1层1户+看房方便+送车位+高区看湖景  个人产权  普通住宅  NaN  2006年  454.82
# 65          老客户转让，首付20万，可，1梯1户，专车接送看房  个人产权  普通住宅  NaN  2017年   82.00
#
#           户型        楼层       物 业 费 物业类型   结构   装修      總價
# 2   4室2厅0厨2卫  高层(共40层)   3.5元/平米・月   住宅  NaN  精装修  2650.0
# 12  2室0厅0厨1卫   高层(共6层)   0.6元/平米・月   住宅  NaN  中装修   180.0
# 27  2室2厅0厨1卫  中层(共15层)         NaN   住宅  NaN   毛坯    80.0
# 60  5室3厅2厨4卫  高层(共21层)  14.5元/平米・月   住宅  NaN  精装修  5500.0
# 65  3室2厅1厨2卫  低层(共17层)         NaN   住宅   平层   毛坯    69.0

# %%
df = df.dropna(axis=0,how='all')
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %% [markdown]
# ## 补齐缺失值

# %%
df['物 业 费'] = df['物 业 费'].fillna(0)

# %%
df.head()
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
# 4   满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权  普通住宅   钢混  1998年   58.00  2室1厅1厨1卫
# 7           纪联小区，，大一房一厅，精装修，，！诚售  个人产权  普通住宅   板楼  1996年   50.00  1室1厅1厨1卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)          0   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0
# 4   高层(共6层)  0.4元/平米・月   住宅   平层  精装修   190.0
# 7   中层(共6层)          0   住宅   平层  精装修   230.0

# %%
df['總價'].isnull().any()
# Out:
# True

# %%
df['總價'].isnull().sum()
# Out:
# 2

# %%
df[df['總價'].isnull()]
# Out:
#                                標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型  \
# 18   光新路191弄 南北通透两室户 地段佳 出行方便满五少税  个人产权  普通住宅   板楼  1990年  47.00  2室1厅1厨1卫
# 175                     精品好房 稍纵即逝  个人产权  普通住宅   钢混  2014年  99.38  3室2厅1厨2卫
#
#            楼层      物 业 费 物业类型  结构   装修  總價
# 18    低层(共6层)  0.3元/平米・月   住宅  平层  精装修 NaN
# 175  中层(共11层)   1.95元/・月   住宅  平层  精装修 NaN

# %%
(df['總價']/df['建筑面积']).mean()
# Out:
# 4.530259387771746

# %%
df['總價'] = df['總價'].fillna(df['建筑面积']*((df['總價']/df['建筑面积']).mean()))

# %%
df.iloc[17,:]
# Out:
# 標題       金都花好悦园五期，精装南北通2房 中心位置，田园外国语小学
# 产权性质                              个人产权
# 住宅类别                              普通住宅
# 建筑类别                                板楼
# 年代                               2004年
# 建筑面积                              90.0
# 户型                            2室2厅1厨1卫
# 楼层                             中层(共6层)
# 物 业 费                        0.8元/平米・月
# 物业类型                                住宅
# 结构                                  平层
# 装修                                 精装修
# 總價                               420.0
# Name: 22, dtype: object

# %%
df['總價'].isnull().any()
# Out:
# False

# %%
df.to_csv('house_final.csv', index_label=False)
