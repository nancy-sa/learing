# %%
import pandas
df = pandas.read_excel('Data\house_price_regression.xlsx')
df.head()
# Out:
#    Unnamed: 0                                             url  \
# 0           0  http://esf.sh.fang.com/chushou/3_289079207.htm
# 1           1  http://esf.sh.fang.com/chushou/3_290295785.htm
# 2           2  http://esf.sh.fang.com/chushou/3_290971789.htm
# 3           3  http://esf.sh.fang.com/chushou/3_290987582.htm
# 4           4  http://esf.sh.fang.com/chushou/3_291070232.htm
#
#                                title  \
# 0  新出笋盘,业主急售,低于市场价30万,精装南北通,近11/12号线
# 1  业主急抛,低于市场价50万,双南双天井,闹中取静,近3/12号线!
# 2  新出笋盘 近11号线 东边套 低于市价50万 送20平米花园 急售
# 3      业主出国急售:板式两房,精装修全明,带产权车位,看房方便!
# 4   徐汇滨江板块,双南两居,小高层带电梯,使用面积大,近3,11号线
#
#                                           age  area  \
# 0  建筑年代：1998_x000D_\n                            65
# 1  建筑年代：1996_x000D_\n                            90
# 2  建筑年代：1998_x000D_\n                            72
# 3  建筑年代：2006_x000D_\n                            96
# 4  建筑年代：1996_x000D_\n                            86
#
#                                      floor_info  \
# 0  中层(共6层)_x000D_\n
# 1  低层(共6层)_x000D_\n
# 2  低层(共6层)_x000D_\n
# 3  高层(共7层)_x000D_\n
# 4  中层(共7层)_x000D_\n
#
#                                   direction  \
# 0  南北向_x000D_\n
# 1  南北向_x000D_\n
# 2   南向_x000D_\n
# 3  南北向_x000D_\n
# 4   南向_x000D_\n
#
#                                               layout    price
# 0  _x000D_\n                            2室1厅_x000...  3500000
# 1  _x000D_\n                            3室2厅_x000...  5000000
# 2  _x000D_\n                            2室1厅_x000...  3980000
# 3  _x000D_\n                            2室2厅_x000...  5500000
# 4  _x000D_\n                            2室1厅_x000...  4500000

# %% [markdown]
# ## 房屋资料处理

# %%
df['age'] = df['age'].map(lambda e:2023-int(e.split("：")[1].split("_")[0]))

# %%
df
# Out:
#       Unnamed: 0                                             url  \
# 0              0  http://esf.sh.fang.com/chushou/3_289079207.htm
# 1              1  http://esf.sh.fang.com/chushou/3_290295785.htm
# 2              2  http://esf.sh.fang.com/chushou/3_290971789.htm
# 3              3  http://esf.sh.fang.com/chushou/3_290987582.htm
# 4              4  http://esf.sh.fang.com/chushou/3_291070232.htm
# ...          ...                                             ...
# 2787        2787  http://esf.sh.fang.com/chushou/3_291344666.htm
# 2788        2788  http://esf.sh.fang.com/chushou/3_291345188.htm
# 2789        2789  http://esf.sh.fang.com/chushou/3_291453462.htm
# 2790        2790  http://esf.sh.fang.com/chushou/3_290043948.htm
# 2791        2791  http://esf.sh.fang.com/chushou/3_285078403.htm
#
#                                    title  age  area  \
# 0      新出笋盘,业主急售,低于市场价30万,精装南北通,近11/12号线   25    65
# 1      业主急抛,低于市场价50万,双南双天井,闹中取静,近3/12号线!   27    90
# 2      新出笋盘 近11号线 东边套 低于市价50万 送20平米花园 急售   25    72
# 3          业主出国急售:板式两房,精装修全明,带产权车位,看房方便!   17    96
# 4       徐汇滨江板块,双南两居,小高层带电梯,使用面积大,近3,11号线   27    86
# ...                                  ...  ...   ...
# 2787      业主可接受下家置换,满五年售后公房税费少,高区景观房近宜德苑   20    92
# 2788      诚售,送固定车位,精装修满五年,可接受下家置换,近漕河景苑!   21   136
# 2789      业主可接受置换,三房房型正气,满五税费少,9号线桂林路!急售   18   125
# 2790  稀.缺两房 品质小区 板式南北通户型 带固定车位 近轨道3 12号线   20   108
# 2791      三江小区 稀缺户型 中装 业主急售 看房随时 师三附小!!!   27    35
#
#                                          floor_info  \
# 0      中层(共6层)_x000D_\n
# 1      低层(共6层)_x000D_\n
# 2      低层(共6层)_x000D_\n
# 3      高层(共7层)_x000D_\n
# 4      中层(共7层)_x000D_\n
# ...                                             ...
# 2787  中层(共24层)_x000D_\n
# 2788  高层(共11层)_x000D_\n
# 2789  高层(共16层)_x000D_\n
# 2790  中层(共18层)_x000D_\n
# 2791   高层(共6层)_x000D_\n
#
#                                      direction  \
# 0     南北向_x000D_\n
# 1     南北向_x000D_\n
# 2      南向_x000D_\n
# 3     南北向_x000D_\n
# 4      南向_x000D_\n
# ...                                        ...
# 2787  南北向_x000D_\n
# 2788  南北向_x000D_\n
# 2789  南北向_x000D_\n
# 2790   南向_x000D_\n
# 2791   南向_x000D_\n
#
#                                                  layout    price
# 0     _x000D_\n                            2室1厅_x000...  3500000
# 1     _x000D_\n                            3室2厅_x000...  5000000
# 2     _x000D_\n                            2室1厅_x000...  3980000
# 3     _x000D_\n                            2室2厅_x000...  5500000
# 4     _x000D_\n                            2室1厅_x000...  4500000
# ...                                                 ...      ...
# 2787  _x000D_\n                            2室2厅_x000...  5000000
# 2788  _x000D_\n                            3室2厅_x000...  9400000
# 2789  _x000D_\n                            3室2厅_x000...  5500000
# 2790  _x000D_\n                            2室2厅_x000...  7410000
# 2791  _x000D_\n                            1室0厅_x000...  3100000
#
# [2792 rows x 9 columns]

# %%
df['total_floor'] = df['floor_info'].str.extract('(\d+)层')
df['total_floor'] = df['total_floor'].astype(int)

# %%
df['floor']  = df['floor_info'].str.extract('^(.)层')

# %%
df
# Out:
#       Unnamed: 0                                             url  \
# 0              0  http://esf.sh.fang.com/chushou/3_289079207.htm
# 1              1  http://esf.sh.fang.com/chushou/3_290295785.htm
# 2              2  http://esf.sh.fang.com/chushou/3_290971789.htm
# 3              3  http://esf.sh.fang.com/chushou/3_290987582.htm
# 4              4  http://esf.sh.fang.com/chushou/3_291070232.htm
# ...          ...                                             ...
# 2787        2787  http://esf.sh.fang.com/chushou/3_291344666.htm
# 2788        2788  http://esf.sh.fang.com/chushou/3_291345188.htm
# 2789        2789  http://esf.sh.fang.com/chushou/3_291453462.htm
# 2790        2790  http://esf.sh.fang.com/chushou/3_290043948.htm
# 2791        2791  http://esf.sh.fang.com/chushou/3_285078403.htm
#
#                                    title  age  area  \
# 0      新出笋盘,业主急售,低于市场价30万,精装南北通,近11/12号线   25    65
# 1      业主急抛,低于市场价50万,双南双天井,闹中取静,近3/12号线!   27    90
# 2      新出笋盘 近11号线 东边套 低于市价50万 送20平米花园 急售   25    72
# 3          业主出国急售:板式两房,精装修全明,带产权车位,看房方便!   17    96
# 4       徐汇滨江板块,双南两居,小高层带电梯,使用面积大,近3,11号线   27    86
# ...                                  ...  ...   ...
# 2787      业主可接受下家置换,满五年售后公房税费少,高区景观房近宜德苑   20    92
# 2788      诚售,送固定车位,精装修满五年,可接受下家置换,近漕河景苑!   21   136
# 2789      业主可接受置换,三房房型正气,满五税费少,9号线桂林路!急售   18   125
# 2790  稀.缺两房 品质小区 板式南北通户型 带固定车位 近轨道3 12号线   20   108
# 2791      三江小区 稀缺户型 中装 业主急售 看房随时 师三附小!!!   27    35
#
#                                          floor_info  \
# 0      中层(共6层)_x000D_\n
# 1      低层(共6层)_x000D_\n
# 2      低层(共6层)_x000D_\n
# 3      高层(共7层)_x000D_\n
# 4      中层(共7层)_x000D_\n
# ...                                             ...
# 2787  中层(共24层)_x000D_\n
# 2788  高层(共11层)_x000D_\n
# 2789  高层(共16层)_x000D_\n
# 2790  中层(共18层)_x000D_\n
# 2791   高层(共6层)_x000D_\n
#
#                                      direction  \
# 0     南北向_x000D_\n
# 1     南北向_x000D_\n
# 2      南向_x000D_\n
# 3     南北向_x000D_\n
# 4      南向_x000D_\n
# ...                                        ...
# 2787  南北向_x000D_\n
# 2788  南北向_x000D_\n
# 2789  南北向_x000D_\n
# 2790   南向_x000D_\n
# 2791   南向_x000D_\n
#
#                                                  layout    price  total_floor  \
# 0     _x000D_\n                            2室1厅_x000...  3500000            6
# 1     _x000D_\n                            3室2厅_x000...  5000000            6
# 2     _x000D_\n                            2室1厅_x000...  3980000            6
# 3     _x000D_\n                            2室2厅_x000...  5500000            7
# 4     _x000D_\n                            2室1厅_x000...  4500000            7
# ...                                                 ...      ...          ...
# 2787  _x000D_\n                            2室2厅_x000...  5000000           24
# 2788  _x000D_\n                            3室2厅_x000...  9400000           11
# 2789  _x000D_\n                            3室2厅_x000...  5500000           16
# 2790  _x000D_\n                            2室2厅_x000...  7410000           18
# 2791  _x000D_\n                            1室0厅_x000...  3100000            6
#
#      floor
# 0        中
# 1        低
# 2        低
# 3        高
# 4        中
# ...    ...
# 2787     中
# 2788     高
# 2789     高
# 2790     中
# 2791     高
#
# [2792 rows x 11 columns]

# %%
df['direction'] = df['direction'].map(lambda e:e.split("_")[0])

# %%
df
# Out:
#       Unnamed: 0                                             url  \
# 0              0  http://esf.sh.fang.com/chushou/3_289079207.htm
# 1              1  http://esf.sh.fang.com/chushou/3_290295785.htm
# 2              2  http://esf.sh.fang.com/chushou/3_290971789.htm
# 3              3  http://esf.sh.fang.com/chushou/3_290987582.htm
# 4              4  http://esf.sh.fang.com/chushou/3_291070232.htm
# ...          ...                                             ...
# 2787        2787  http://esf.sh.fang.com/chushou/3_291344666.htm
# 2788        2788  http://esf.sh.fang.com/chushou/3_291345188.htm
# 2789        2789  http://esf.sh.fang.com/chushou/3_291453462.htm
# 2790        2790  http://esf.sh.fang.com/chushou/3_290043948.htm
# 2791        2791  http://esf.sh.fang.com/chushou/3_285078403.htm
#
#                                    title  age  area  \
# 0      新出笋盘,业主急售,低于市场价30万,精装南北通,近11/12号线   25    65
# 1      业主急抛,低于市场价50万,双南双天井,闹中取静,近3/12号线!   27    90
# 2      新出笋盘 近11号线 东边套 低于市价50万 送20平米花园 急售   25    72
# 3          业主出国急售:板式两房,精装修全明,带产权车位,看房方便!   17    96
# 4       徐汇滨江板块,双南两居,小高层带电梯,使用面积大,近3,11号线   27    86
# ...                                  ...  ...   ...
# 2787      业主可接受下家置换,满五年售后公房税费少,高区景观房近宜德苑   20    92
# 2788      诚售,送固定车位,精装修满五年,可接受下家置换,近漕河景苑!   21   136
# 2789      业主可接受置换,三房房型正气,满五税费少,9号线桂林路!急售   18   125
# 2790  稀.缺两房 品质小区 板式南北通户型 带固定车位 近轨道3 12号线   20   108
# 2791      三江小区 稀缺户型 中装 业主急售 看房随时 师三附小!!!   27    35
#
#                                          floor_info direction  \
# 0      中层(共6层)_x000D_\n                                   南北向
# 1      低层(共6层)_x000D_\n                                   南北向
# 2      低层(共6层)_x000D_\n                                    南向
# 3      高层(共7层)_x000D_\n                                   南北向
# 4      中层(共7层)_x000D_\n                                    南向
# ...                                             ...       ...
# 2787  中层(共24层)_x000D_\n                                   南北向
# 2788  高层(共11层)_x000D_\n                                   南北向
# 2789  高层(共16层)_x000D_\n                                   南北向
# 2790  中层(共18层)_x000D_\n                                    南向
# 2791   高层(共6层)_x000D_\n                                    南向
#
#                                                  layout    price  total_floor  \
# 0     _x000D_\n                            2室1厅_x000...  3500000            6
# 1     _x000D_\n                            3室2厅_x000...  5000000            6
# 2     _x000D_\n                            2室1厅_x000...  3980000            6
# 3     _x000D_\n                            2室2厅_x000...  5500000            7
# 4     _x000D_\n                            2室1厅_x000...  4500000            7
# ...                                                 ...      ...          ...
# 2787  _x000D_\n                            2室2厅_x000...  5000000           24
# 2788  _x000D_\n                            3室2厅_x000...  9400000           11
# 2789  _x000D_\n                            3室2厅_x000...  5500000           16
# 2790  _x000D_\n                            2室2厅_x000...  7410000           18
# 2791  _x000D_\n                            1室0厅_x000...  3100000            6
#
#      floor
# 0        中
# 1        低
# 2        低
# 3        高
# 4        中
# ...    ...
# 2787     中
# 2788     高
# 2789     高
# 2790     中
# 2791     高
#
# [2792 rows x 11 columns]

# %%
df[['room', 'living_room']] = df['layout'].str.extract("(\d+)室(\d+)厅")
df['room'] = df['room'].astype(int)
df['living_room'] = df['living_room'].astype(int)

# %%
del df['layout']
del df['floor_info']
del df['title']
del df['url']
df
# Out:
#       Unnamed: 0  age  area direction    price  total_floor floor  room  \
# 0              0   25    65       南北向  3500000            6     中     2
# 1              1   27    90       南北向  5000000            6     低     3
# 2              2   25    72        南向  3980000            6     低     2
# 3              3   17    96       南北向  5500000            7     高     2
# 4              4   27    86        南向  4500000            7     中     2
# ...          ...  ...   ...       ...      ...          ...   ...   ...
# 2787        2787   20    92       南北向  5000000           24     中     2
# 2788        2788   21   136       南北向  9400000           11     高     3
# 2789        2789   18   125       南北向  5500000           16     高     3
# 2790        2790   20   108        南向  7410000           18     中     2
# 2791        2791   27    35        南向  3100000            6     高     1
#
#       living_room
# 0               1
# 1               2
# 2               1
# 3               2
# 4               1
# ...           ...
# 2787            2
# 2788            2
# 2789            2
# 2790            2
# 2791            0
#
# [2792 rows x 9 columns]

# %%
df = pandas.concat([df, pandas.get_dummies(df['direction']), pandas.get_dummies(df['floor'])], axis = 1 )
df.head()
# Out:
#    Unnamed: 0  age  area direction    price  total_floor floor  room  \
# 0           0   25    65       南北向  3500000            6     中     2
# 1           1   27    90       南北向  5000000            6     低     3
# 2           2   25    72        南向  3980000            6     低     2
# 3           3   17    96       南北向  5500000            7     高     2
# 4           4   27    86        南向  4500000            7     中     2
#
#    living_room    东南向     东向    南北向     南向    西南向     西向      中      低      高
# 0            1  False  False   True  False  False  False   True  False  False
# 1            2  False  False   True  False  False  False  False   True  False
# 2            1  False  False  False   True  False  False  False   True  False
# 3            2  False  False   True  False  False  False  False  False   True
# 4            1  False  False  False   True  False  False   True  False  False

# %%
del df['南北向']
del df['低']
del df['direction']
del df['floor']

# %% [markdown]
# ## 绘制散点图

# %%
# %matplotlib inline
df[['price', 'area']].plot(kind='scatter', x = 'area', y = 'price', figsize=[10,5])
# Out:
# <Axes: xlabel='area', ylabel='price'>

# %%
y= df['price']
X = df[['area']]

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#       2 regr = LinearRegression()
#       3 regr.fit(X,y)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
print('Coefficient:{}'.format(regr.coef_) )
print('Intercept:{}'.format(regr.intercept_) )

# %%
plt.scatter(X,y, color="blue")
plt.plot(X, regr.predict(X), linewidth = 3, color = "red")
plt.xlabel('area')
plt.ylabel('price')

# %% [markdown]
# ### 多元回归预测

# %%
y= df['price'].values
X = df[['age', 'area', 'room', 'living_room', 'total_floor', '东南向', '东向', '南向', '西南向', '西向', '中', '高']]

# %%
from sklearn.linear_model import LinearRegression
regr = LinearRegression()
regr.fit(X,y)

# %% [markdown]
# ### 评估模型

# %%
import statsmodels.api as sm
X2 = sm.add_constant(X)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())

# %% [markdown]
# ### 通过aic确定最佳回归组合

# %%
predictorcols = ['age', 'area', 'room', 'living_room', 'total_floor', '东南向', '东向', '南向', '西南向', '西向', '中', '高']
import itertools
AICs = {}
for k in range(1,len(predictorcols)+1):
    for variables in itertools.combinations(predictorcols, k):
        predictors  = X[list(variables)]
        predictors2 = sm.add_constant(predictors)
        est = sm.OLS(y, predictors2)
        res = est.fit()
        AICs[variables] = res.aic

# %%
from collections import Counter
c = Counter(AICs)
c.most_common()[::-10]
