# %%
import requests
url = 'https://sh.esf.fang.com/'
res = requests.get(url)
# print(res.text)

# %%
from bs4 import BeautifulSoup
main = 'https://sh.esf.fang.com/'
soup = BeautifulSoup(res.text,'html.parser')
for line in soup.select('.tit_shop'):
    titel = line.text.strip()
for aline in soup.select('dd>h4 a'):
    url = main + aline['href']
    print(url)
    #print('==========')
# Out:
# https://sh.esf.fang.com//chushou/3_423453480.htm
# https://sh.esf.fang.com//chushou/3_423802831.htm
# https://sh.esf.fang.com//chushou/3_423817992.htm
# https://sh.esf.fang.com//chushou/3_420628522.htm
# https://sh.esf.fang.com//chushou/3_422991211.htm
# https://sh.esf.fang.com//chushou/3_423479572.htm
# https://sh.esf.fang.com//chushou/3_423567842.htm
# https://sh.esf.fang.com//chushou/3_422844524.htm
# https://sh.esf.fang.com//chushou/3_423650351.htm
# https://sh.esf.fang.com//chushou/3_423735248.htm
# https://sh.esf.fang.com//chushou/3_423801409.htm
# https://sh.esf.fang.com//chushou/3_422960781.htm
# https://sh.esf.fang.com//chushou/3_423735256.htm
# https://sh.esf.fang.com//chushou/3_423855697.htm
# https://sh.esf.fang.com//chushou/3_412230501.htm
# https://sh.esf.fang.com//chushou/3_423080995.htm
# https://sh.esf.fang.com//chushou/3_423735259.htm
# https://sh.esf.fang.com//chushou/3_423564393.htm
# https://sh.esf.fang.com//chushou/3_423735273.htm
# ...

# %% [markdown]
# #### 爬取来的网页需加上后缀才能得到真正的网页
# #### 这个是动态数据
# #### selenium方法被检测到了，导致触发了滑块验证

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://sh.esf.fang.com/chushou/3_423453480.htm?channel=2,2&psid=1_1_60'
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}
res = requests.get(url,headers=header)
soup = BeautifulSoup(res.text,'html.parser')
print(soup)
# Out:
# <html lang="UTF-8" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible">
# <meta content="webkit" name="renderer"/>
# <title>跳转...</title>
# <link href="//img.soufun.com/news/image/newscenter/20111107zt/goufangzhinan/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//js.soufunimg.com/homepage/newsgroup/news_front_desk/20131107/css/newStyle201412.css?v=201605041016" rel="stylesheet" type="text/css"/>
# <link href="//js.soufunimg.com/homepage/newsgroup/news_front_desk/20131107/css/tools.css?v=201605041016" rel="stylesheet" type="text/css"/>
# <link href="//js.soufunimg.com/homepage/newsgroup/news_front_desk/20131107/css/newsNav.css?v=201605041016" rel="stylesheet" type="text/css"/>
# <link href="./auto_redirect.css?v=201905041016" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.select('.tit_text')
# Out:
# []
